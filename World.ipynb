# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set()

# %%
unemployment_df=pd.read_csv(r'D:\Python\Projects\World Economic Data\unemployment.csv')

# %%
unemployment_df.head()
# Out:
#             country  unemployment_rate
# 0  Marshall Islands               36.0
# 1      South Africa               33.6
# 2          Kiribati               30.6
# 3            Kosovo               30.5
# 4    American Samoa               29.8

# %%
unemployment_df.shape
# Out:
# (64, 2)

# %%
unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            64 non-null     object
#  1   unemployment_rate  64 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ KB

# %%
unemployment_df.describe()
# Out:
#        unemployment_rate
# count          64.000000
# mean            7.823437
# std             8.806685
# min             0.100000
# 25%             2.700000
# 50%             5.000000
# 75%             8.250000
# max            36.000000

# %%
unemployment_df['country'].unique()
# Out:
# array(['Marshall Islands', 'South Africa', 'Kiribati', 'Kosovo',
#        'American Samoa', 'Djibouti', 'Eswatini', 'Greece', 'Spain',
#        'Brazil', 'Turkey', 'Italy', 'Nigeria', 'Egypt', 'Ukraine',
#        'Sweden', 'France', 'Canada', 'Saudi Arabia', 'Bermuda', 'Ireland',
#        'Ecuador', 'India', 'United States', 'Sri Lanka', 'Hong Kong',
#        'Switzerland', 'Bangladesh', 'Luxembourg', 'Romania', 'Australia',
#        'Norway', 'Russia', 'China', 'Denmark', 'Malaysia',
#        'United Kingdom', 'Indonesia', 'Mexico', 'Pakistan', 'Netherlands',
#        'Taiwan', 'Singapore', 'South Korea', 'Germany', 'Poland', 'Macao',
#        'Japan', 'Philippines', 'Vietnam', 'Principality of Monaco',
#        'Bahrain', 'Chad', 'Burundi', 'Benin', 'Thailand', 'Laos',
#        'Guernsey', 'Isle of Man', 'Gibraltar', 'Niger', 'Cambodia',
#        'Qatar', 'Cocos (Keeling) Islands'], dtype=object)

# %%
len(unemployment_df['country'].unique())
# Out:
# 64

# %%
unemployment_df.plot(x='country', y='unemployment_rate', rot=90, kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='country'>

# %%
unemployment_df['unemployment_rate'].mean()
# Out:
# 7.8234375

# %%
len(unemployment_df[unemployment_df['unemployment_rate']<7.8234375])
# Out:
# 47

# %% [markdown]
# # Top 10 Countries with highest unemployment rate

# %%
top10_unemployment_df=unemployment_df.sort_values(['unemployment_rate'],ascending=False)[:10]
top10_unemployment_df
# Out:
#             country  unemployment_rate
# 0  Marshall Islands               36.0
# 1      South Africa               33.6
# 2          Kiribati               30.6
# 3            Kosovo               30.5
# 4    American Samoa               29.8
# 5          Djibouti               28.4
# 6          Eswatini               25.8
# 7            Greece               14.8
# 8             Spain               14.7
# 9            Brazil               14.4

# %%
top10_unemployment_df.plot(x='country', y= 'unemployment_rate',rot=70, kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='country'>

# %%
rich_country=pd.read_csv(r'D:\Python\Projects\World Economic Data\richest_countries.csv')
rich_country.head()
# Out:
#       country  gdp_per_capita
# 0  Luxembourg          134754
# 1   Singapore          116486
# 2     Ireland          106456
# 3       Qatar           93521
# 4     Bermuda           85192

# %%
rich_country.shape
# Out:
# (50, 2)

# %%
rich_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         50 non-null     object
#  1   gdp_per_capita  50 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 932.0+ bytes

# %%
rich_country.describe()
# Out:
#        gdp_per_capita
# count       50.000000
# mean     54088.180000
# std      22709.045634
# min      30422.000000
# 25%      36940.500000
# 50%      47316.000000
# 75%      62656.250000
# max     134754.000000

# %%
len(rich_country['country'].unique())
# Out:
# 50

# %%
rich_country.isna().sum()
# Out:
# country           0
# gdp_per_capita    0
# dtype: int64

# %%
rich_country.plot(x='country', y='gdp_per_capita', rot=90, kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='country'>

# %%
rich_country['gdp_per_capita'].mean()
# Out:
# 54088.18

# %%
len(rich_country[rich_country['gdp_per_capita']<54088.18])
# Out:
# 30

# %%
top10_rich_country=rich_country.sort_values(['gdp_per_capita'],ascending=False)[:10]
top10_rich_country
# Out:
#          country  gdp_per_capita
# 0     Luxembourg          134754
# 1      Singapore          116486
# 2        Ireland          106456
# 3          Qatar           93521
# 4        Bermuda           85192
# 5         Norway           79201
# 6    Switzerland           77324
# 7          Macao           73802
# 8  United States           69288
# 9         Brunei           66620

# %%
top10_rich_country.plot(x='country',y='gdp_per_capita', rot=70, kind='bar',figsize=(12,6))
# Out:
# <Axes: xlabel='country'>

# %%
tourism_df=pd.read_csv(r'D:\Python\Projects\World Economic Data\tourism.csv')

# %%
tourism_df.head()
# Out:
#          country  tourists_in_millions  receipts_in_billions  \
# 0         France                 117.1                 35.96
# 1         Mexico                  51.1                 11.45
# 2  United States                  45.0                 84.21
# 3          Italy                  38.4                 20.46
# 4        Hungary                  31.6                  4.22
#
#    receipts_per_tourist  percentage_of_gdp
# 0                   307                1.2
# 1                   224                0.9
# 2                  1870                0.4
# 3                   533                1.0
# 4                   133                2.3

# %%
tourism_df.shape
# Out:
# (41, 5)

# %%
tourism_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   country               41 non-null     object
#  1   tourists_in_millions  41 non-null     float64
#  2   receipts_in_billions  41 non-null     float64
#  3   receipts_per_tourist  41 non-null     int64
#  4   percentage_of_gdp     41 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.7+ KB

# %%
len(tourism_df['country'].unique())
# Out:
# 41

# %%
tourism_df.isna().sum()
# Out:
# country                 0
# tourists_in_millions    0
# receipts_in_billions    0
# receipts_per_tourist    0
# percentage_of_gdp       0
# dtype: int64

# %%
d=tourism_df.corr()
d
# Out:
# C:\Users\ANKIT SINGH\AppData\Local\Temp\ipykernel_72660\2755841955.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=tourism_df.corr()
#                       tourists_in_millions  receipts_in_billions  \
# tourists_in_millions              1.000000              0.468412
# receipts_in_billions              0.468412              1.000000
# receipts_per_tourist             -0.224636              0.158790
# percentage_of_gdp                -0.099293             -0.048773
#
#                       receipts_per_tourist  percentage_of_gdp
# tourists_in_millions             -0.224636          -0.099293
# receipts_in_billions              0.158790          -0.048773
# receipts_per_tourist              1.000000           0.103868
# percentage_of_gdp                 0.103868           1.000000

# %%
plt.figure(figsize=(10,5), dpi=100)
sns.heatmap(d,annot=True)
plt.show()

# %%
tourism_df.describe()
# Out:
#        tourists_in_millions  receipts_in_billions  receipts_per_tourist  \
# count             41.000000             41.000000             41.000000
# mean              11.209756             11.256341           2930.512195
# std               20.819376             16.595482           4735.728456
# min                0.000000              0.090000             80.000000
# 25%                2.500000              2.200000            533.000000
# 50%                4.100000              4.510000           1018.000000
# 75%                8.100000             11.780000           2882.000000
# max              117.100000             84.210000          24601.000000
#
#        percentage_of_gdp
# count          41.000000
# mean            3.482927
# std             5.519914
# min             0.200000
# 25%             0.800000
# 50%             1.700000
# 75%             3.400000
# max            31.600000

# %%
tourists_tourism_df=tourism_df.sort_values(by=['tourists_in_millions'],ascending=False)

# %%
tourists_tourism_df.plot(y='tourists_in_millions',x='country', rot=90, kind='bar', figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top10_tourism_df=tourism_df.sort_values(['tourists_in_millions'],ascending=False)[:10]
top10_tourism_df
# Out:
#           country  tourists_in_millions  receipts_in_billions  \
# 0          France                 117.1                 35.96
# 1          Mexico                  51.1                 11.45
# 2   United States                  45.0                 84.21
# 3           Italy                  38.4                 20.46
# 4         Hungary                  31.6                  4.22
# 5         Croatia                  21.6                  5.63
# 6          Turkey                  16.0                 13.77
# 7         Austria                  15.1                 15.36
# 8         Germany                  12.4                 58.37
# 9  Virgin Islands                   8.6                  0.69
#
#    receipts_per_tourist  percentage_of_gdp
# 0                   307                1.2
# 1                   224                0.9
# 2                  1870                0.4
# 3                   533                1.0
# 4                   133                2.3
# ...

# %%
top10_tourism_df.plot(y='tourists_in_millions',x='country', rot=90, kind='bar', figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
tourism_df['tourists_in_millions'].mean()
# Out:
# 11.209756097560975

# %%
len(tourism_df[tourism_df['tourists_in_millions']>11.209756097560975])
# Out:
# 9

# %%
tourism_df.sort_values(['tourists_in_millions'],ascending=False)[:3]
# Out:
#          country  tourists_in_millions  receipts_in_billions  \
# 0         France                 117.1                 35.96
# 1         Mexico                  51.1                 11.45
# 2  United States                  45.0                 84.21
#
#    receipts_per_tourist  percentage_of_gdp
# 0                   307                1.2
# 1                   224                0.9
# 2                  1870                0.4

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=top10_tourism_df,x='tourists_in_millions',y='receipts_in_billions', marker='o')
plt.show()

# %%
plt.figure(figsize=(15,6),dpi=200)
sns.regplot(data=tourism_df,x='tourists_in_millions',y='receipts_in_billions', marker='o')
plt.show()

# %%
reciepts_tourism_df=tourism_df.sort_values(by=['receipts_in_billions'],ascending=False)

# %%
reciepts_tourism_df.plot(y='receipts_in_billions', x='country', rot=90, kind='bar',figsize=(15,6))
# Out:
# <Axes: xlabel='country'>

# %%
top10_reciepts_tourism_df=reciepts_tourism_df.sort_values(['receipts_in_billions'],ascending=False)[:10]

# %%
top10_reciepts_tourism_df[['country','receipts_in_billions','tourists_in_millions']]
# Out:
#                  country  receipts_in_billions  tourists_in_millions
# 2          United States                 84.21                  45.0
# 8                Germany                 58.37                  12.4
# 0                 France                 35.96                 117.1
# 25             Hong Kong                 32.70                   3.6
# 31             Australia                 26.23                   1.8
# 10  United Arab Emirates                 24.62                   8.1
# 3                  Italy                 20.46                  38.4
# 7                Austria                 15.36                  15.1
# 35                 Qatar                 14.32                   0.6
# 6                 Turkey                 13.77                  16.0

# %%
top10_reciepts_tourism_df.plot(y='receipts_in_billions',x='country', kind='bar', rot=90, figsize=(15,6))
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# Total no.of Receipts = receipts_per_tourist * tourists_in_millions

# %% [markdown]
# For United States

# %%
top10_reciepts_tourism_df.iloc[0]['receipts_per_tourist'] * top10_reciepts_tourism_df.iloc[0]['tourists_in_millions']
# Out:
# 84150.0

# %% [markdown]
# For France

# %%
top10_reciepts_tourism_df.iloc[2]['receipts_per_tourist'] * top10_reciepts_tourism_df.iloc[2]['tourists_in_millions']
# Out:
# 35949.7

# %%
reciepts_per_tourist_tourism_df=tourism_df.sort_values(['receipts_per_tourist'],ascending=False)
reciepts_per_tourist_tourism_df.plot(y='receipts_per_tourist',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top10_reciepts_per_tourist_tourism_df=tourism_df.sort_values(['receipts_per_tourist'],ascending=False)[:10]
top10_reciepts_per_tourist_tourism_df
# Out:
#                  country  tourists_in_millions  receipts_in_billions  \
# 35                 Qatar                   0.6                 14.32
# 31             Australia                   1.8                 26.23
# 40               Moldova                   0.0                  0.35
# 25             Hong Kong                   3.6                 32.70
# 36            Luxembourg                   0.5                  4.45
# 8                Germany                  12.4                 58.37
# 30           South Korea                   2.5                 11.78
# 37              Ethiopia                   0.5                  2.28
# 38                Serbia                   0.4                  1.42
# 10  United Arab Emirates                   8.1                 24.62
#
#     receipts_per_tourist  percentage_of_gdp
# 35                 24601                8.0
# 31                 14351                1.7
# 40                 12207                2.6
# ...

# %%
top10_reciepts_per_tourist_tourism_df.plot(y='receipts_per_tourist',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
percentage_of_gdp_tourism_df=tourism_df.sort_values(['percentage_of_gdp'],ascending=False)
percentage_of_gdp_tourism_df.plot(y='percentage_of_gdp', x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top110_percentage_of_gdp_tourism_df=tourism_df.sort_values(['percentage_of_gdp'],ascending=False)[:10]
top110_percentage_of_gdp_tourism_df.plot(y='percentage_of_gdp', x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
corruption_df=pd.read_csv(r'D:\Python\Projects\World Economic Data\corruption.csv')
corruption_df.head()
# Out:
#        country  annual_income  corruption_index
# 0      Denmark          68110                12
# 1      Finland          53660                12
# 2  New Zealand          45340                12
# 3       Norway          84090                15
# 4    Singapore          64010                15

# %%
corruption_df.shape
# Out:
# (110, 3)

# %%
len(corruption_df['country'].unique())
# Out:
# 110

# %%
corruption_df.isna().sum()
# Out:
# country             0
# annual_income       0
# corruption_index    0
# dtype: int64

# %%
d=corruption_df.corr()
d
# Out:
# C:\Users\ANKIT SINGH\AppData\Local\Temp\ipykernel_72660\2112852372.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=corruption_df.corr()
#                   annual_income  corruption_index
# annual_income          1.000000         -0.916669
# corruption_index      -0.916669          1.000000

# %%
plt.figure(figsize=(4,2),dpi=100)
sns.heatmap(d,annot=True)
plt.show()

# %%
corruption_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           110 non-null    object
#  1   annual_income     110 non-null    int64
#  2   corruption_index  110 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 2.7+ KB

# %%
corruption_df.describe()
# Out:
#        annual_income  corruption_index
# count     110.000000        110.000000
# mean    17195.727273         59.200000
# std     23741.147397         22.170234
# min       240.000000         12.000000
# 25%      1470.000000         41.750000
# 50%      4130.000000         69.000000
# 75%     25410.000000         75.000000
# max     90360.000000         89.000000

# %%
income_corruption_df=corruption_df.sort_values(['annual_income'],ascending=False)
income_corruption_df.plot(y='annual_income',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top10_income_corruption_df=corruption_df.sort_values(['annual_income'],ascending=False)[:10]
top10_income_corruption_df
# Out:
#           country  annual_income  corruption_index
# 6     Switzerland          90360                16
# 3          Norway          84090                15
# 8      Luxembourg          81110                19
# 16        Ireland          74520                26
# 22  United States          70430                33
# 0         Denmark          68110                12
# 15        Iceland          64410                26
# 4       Singapore          64010                15
# 5          Sweden          58890                15
# 23          Qatar          57120                37

# %%
top10_income_corruption_df.plot(y='annual_income',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
corruption_index_corruption_df=corruption_df.sort_values(['corruption_index'],ascending=False)
corruption_index_corruption_df
# Out:
#          country  annual_income  corruption_index
# 109  South Sudan            460                89
# 108        Syria           1170                87
# 107      Somalia            450                87
# 106    Venezuela          13080                86
# 105        Yemen            670                84
# ..           ...            ...               ...
# 3         Norway          84090                15
# 5         Sweden          58890                15
# 2    New Zealand          45340                12
# 1        Finland          53660                12
# 0        Denmark          68110                12
#
# [110 rows x 3 columns]

# %%
corruption_index_corruption_df.plot(y='corruption_index', x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top10_corruption_index_corruption_df=corruption_df.sort_values(['corruption_index'], ascending=False)[:10]
top10_corruption_index_corruption_df.plot(y='corruption_index', x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
display(corruption_index_corruption_df[corruption_index_corruption_df['country'] == 'Switzerland'])
display(corruption_index_corruption_df[corruption_index_corruption_df['country'] == 'Norway'])
display(corruption_index_corruption_df[corruption_index_corruption_df['country'] == 'Luxembourg'])
# Out:
#        country  annual_income  corruption_index
# 6  Switzerland          90360                16
#   country  annual_income  corruption_index
# 3  Norway          84090                15
#       country  annual_income  corruption_index
# 8  Luxembourg          81110                19

# %%
plt.figure(figsize=(15,8), dpi=200)
sns.regplot(data=corruption_df, y='corruption_index', x='annual_income', marker='o')
plt.show()

# %% [markdown]
# There is a clear negative linear relation between annual income and corruption index and it can be seen from the Above scatter plot. If annual income increases corruption index decreases for a country and vice versa.

# %%
living_df=pd.read_csv(r'D:\Python\Projects\World Economic Data\cost_of_living.csv')
living_df.head()
# Out:
#           country  cost_index  monthly_income  purchasing_power_index
# 0         Bermuda       157.6            9712                   105.0
# 1     Switzerland       142.4            7530                    90.1
# 2  Cayman Islands       137.9            5281                    65.2
# 3          Israel       130.2            4130                    54.1
# 4         Iceland       128.0            5368                    71.5

# %%
living_df.shape
# Out:
# (107, 4)

# %%
living_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 107 non-null    object
#  1   cost_index              107 non-null    float64
#  2   monthly_income          107 non-null    int64
#  3   purchasing_power_index  107 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.5+ KB

# %%
len(living_df['country'].unique())
# Out:
# 107

# %%
d=living_df.corr()
d
# Out:
# C:\Users\ANKIT SINGH\AppData\Local\Temp\ipykernel_72660\1642384732.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=living_df.corr()
#                         cost_index  monthly_income  purchasing_power_index
# cost_index                1.000000        0.872141                0.709241
# monthly_income            0.872141        1.000000                0.918266
# purchasing_power_index    0.709241        0.918266                1.000000

# %%
plt.figure(figsize=(15,8), dpi=150)
sns.heatmap(d,annot=True)
plt.show()

# %%
living_df.describe()
# Out:
#        cost_index  monthly_income  purchasing_power_index
# count  107.000000      107.000000              107.000000
# mean    62.555140     1826.532710               38.150467
# std     33.747716     2100.275033               30.588024
# min     22.800000       87.000000                3.400000
# 25%     36.400000      295.000000               14.050000
# 50%     48.900000      782.000000               25.800000
# 75%     84.550000     3130.000000               59.100000
# max    157.600000     9712.000000              121.100000

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.regplot(data=living_df, x='monthly_income', y='purchasing_power_index', marker='*')
plt.show()

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.regplot(data=living_df, x='monthly_income', y='cost_index', marker='*')
plt.show()

# %%
plt.figure(figsize=(12,6), dpi=150)
sns.regplot(data=living_df, x='purchasing_power_index', y='cost_index', marker='*')
plt.show()

# %%
income_living_df=living_df.sort_values(['monthly_income'],ascending=False)
income_living_df.plot(y='monthly_income', x='country', kind='bar', rot=90, figsize=(15,8))
# Out:
# <Axes: xlabel='country'>

# %%
top10_income_living_df=living_df.sort_values(['monthly_income'],ascending=False)[:10]
top10_income_living_df.plot(y='monthly_income', x='country', kind='bar', rot=90, figsize=(15,8))
# Out:
# <Axes: xlabel='country'>

# %%
purchasing_power_living_df=living_df.sort_values(['purchasing_power_index'],ascending=False)
purchasing_power_living_df.plot(y='purchasing_power_index',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
top10_purchasing_power_living_df=living_df.sort_values(['purchasing_power_index'],ascending=False)[:10]
top10_purchasing_power_living_df
# Out:
#           country  cost_index  monthly_income  purchasing_power_index
# 31      Singapore        75.0            5334                   121.1
# 36          Qatar        71.4            4760                   113.6
# 0         Bermuda       157.6            9712                   105.0
# 13     Luxembourg       113.1            6759                   101.8
# 19  United States       100.0            5869                   100.0
# 28      Hong Kong        77.9            4538                    99.2
# 7          Norway       124.6            7008                    95.9
# 53         Brunei        48.9            2626                    91.4
# 1     Switzerland       142.4            7530                    90.1
# 32          Macao        75.0            3894                    88.5

# %%
top10_purchasing_power_living_df.plot(y='purchasing_power_index',x='country', kind='bar', rot=90, figsize=(20,10))
# Out:
# <Axes: xlabel='country'>

# %%
cost_living_index=living_df.sort_values(['cost_index'], ascending=False)
cost_living_index.plot(y='cost_index', x='country', kind='bar', rot=90, figsize=(15,8))
# Out:
# <Axes: xlabel='country'>

# %%
top10_cost_living_index=living_df.sort_values(['cost_index'], ascending=False)[:10]
top10_cost_living_index
# Out:
#                     country  cost_index  monthly_income  \
# 0                   Bermuda       157.6            9712
# 1               Switzerland       142.4            7530
# 2            Cayman Islands       137.9            5281
# 3                    Israel       130.2            4130
# 4                   Iceland       128.0            5368
# 5             New Caledonia       125.8            1101
# 6  Turks and Caicos Islands       124.6            1967
# 7                    Norway       124.6            7008
# 8                  Barbados       121.5            1393
# 9                   Denmark       119.9            5676
#
#    purchasing_power_index
# 0                   105.0
# 1                    90.1
# 2                    65.2
# 3                    54.1
# 4                    71.5
# 5                    14.9
# 6                    26.9
# 7                    95.9
# 8                    19.5
# 9                    80.6

# %%
top10_cost_living_index.plot(y='cost_index', x='country', kind='bar', rot=90, figsize=(15,8))
# Out:
# <Axes: xlabel='country'>

# %%
income_living_df['monthly_income'].mean()
# Out:
# 1826.5327102803737

# %%
len(income_living_df[income_living_df['monthly_income']>=1826.5327102803737])
# Out:
# 37

# %%
len(income_living_df[income_living_df['monthly_income']>=income_living_df['monthly_income'].mean()])
# Out:
# 37

# %%
purchasing_power_living_df['purchasing_power_index'].mean()
# Out:
# 38.15046728971962

# %%
len(purchasing_power_living_df[purchasing_power_living_df['purchasing_power_index']>=38.15046728971962])
# Out:
# 45

# %%
cost_living_index['cost_index'].mean()
# Out:
# 62.555140186915885

# %%
len(cost_living_index[cost_living_index['cost_index']>=62.555140186915885])
# Out:
# 41
